# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785736   Pekerjaan tetap               False       Singapore
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 785736   Singapore        None              NaN              NaN
# 785737     Germany        None              NaN              NaN
# 785738    Malaysia        None              NaN              NaN
# 785739       Sudan        None              NaN              NaN
# 785740       India        None              NaN              NaN
#
#                               company_name  \
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}

# %%
df.sample()
# Out:
#       job_title_short                    job_title job_location       job_via  \
# 32599   Data Engineer  SUPPORT DATA ENGINEER (H/F)     Anywhere  via LinkedIn
#
#       job_schedule_type  job_work_from_home search_location  \
# 32599         Full-time                True          France
#
#           job_posted_date  job_no_degree_mention  job_health_insurance  \
# 32599 2023-08-03 13:21:05                   True                 False
#
#       job_country salary_rate  salary_year_avg  salary_hour_avg  company_name  \
# 32599      France        None              NaN              NaN  Urban Linker
#
#       job_skills job_type_skills
# 32599       None            None

# %%
df.sample(10)
# Out:
#                   job_title_short                               job_title  \
# 53092                Data Analyst                     Master Data Analyst
# 517298              Data Engineer                   Data Science Engineer
# 586467              Data Engineer                       ETL Data Engineer
# 260490               Data Analyst  InformationTechnology - Data Analyst 2
# 738510              Data Engineer    Data Analytics Engineer | Co. Dublin
# 9592                 Data Analyst                            Data Analyst
# 85567              Data Scientist                          Data Scientist
# 347995               Data Analyst     Data Analyst Warehousing Operations
# 39814                Data Analyst                            Data Analyst
# 137461  Machine Learning Engineer               Machine Learning Engineer
#
#                job_location                                        job_via  \
# 53092      Quilicura, Chile  via Trabajo.org - Vacantes De Empleo, Trabajo
# 517298                Spain                                   via LinkedIn
# 586467  Toronto, ON, Canada                                via Trabajo.org
# 260490     Indianapolis, IN                               via ZipRecruiter
# 738510      Dublin, Ireland                                via Trabajo.org
# 9592                 Canada                               via BeBee Canada
# 85567                  Peru                                 via Emprego.pt
# 347995              Germany                              via Jobrapido.com
# 39814          Callao, Peru  via Trabajo.org - Vacantes De Empleo, Trabajo
# 137461             Malaysia                                     via Jooble
#
#        job_schedule_type  job_work_from_home          search_location  \
# 53092          Full-time               False                    Chile
# 517298         Full-time               False                    Spain
# 586467         Full-time               False                   Canada
# 260490         Full-time               False  Illinois, United States
# 738510         Full-time               False                  Ireland
# 9592           Full-time               False                   Canada
# 85567          Full-time               False                     Peru
# 347995         Full-time               False                  Germany
# 39814          Full-time               False                     Peru
# 137461         Full-time               False                 Malaysia
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 53092  2023-08-04 06:56:34                  False                 False
# 517298 2023-08-24 11:38:48                  False                 False
# 586467 2023-01-06 09:33:26                  False                 False
# 260490 2023-05-16 07:01:55                  False                 False
# 738510 2023-03-01 22:03:58                   True                 False
# 9592   2023-09-06 13:32:27                   True                 False
# 85567  2023-02-03 00:19:02                  False                 False
# 347995 2023-10-13 23:34:51                  False                 False
# 39814  2023-08-27 06:16:16                   True                 False
# 137461 2023-09-06 08:10:24                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 53092           Chile        None              NaN              NaN
# 517298          Spain        None              NaN              NaN
# 586467         Canada        None              NaN              NaN
# 260490  United States        None              NaN              NaN
# 738510        Ireland        None              NaN              NaN
# 9592           Canada        None              NaN              NaN
# 85567            Peru        None              NaN              NaN
# 347995        Germany        None              NaN              NaN
# 39814            Peru        None              NaN              NaN
# 137461       Malaysia        None              NaN              NaN
#
#                  company_name  \
# 53092      The Clorox Company
# 517298         SABIA Personal
# 586467  Tekstaff IT Solutions
# 260490             HireTalent
# 738510        FRS Recruitment
# 9592                LanceSoft
# 85567        Pacifico Seguros
# 347995            Unspecified
# 39814                 Emprego
# 137461                   Zoom
#
#                                                job_skills  \
# 53092   ['visual basic', 'python', 'sql', 'javascript'...
# 517298  ['python', 'scala', 'java', 'sql', 'aws', 'red...
# 586467  ['sql', 't-sql', 'sql server', 'azure', 'gcp',...
# 260490                                               None
# 738510                         ['sql', 'power bi', 'dax']
# 9592                                      ['sql', 'unix']
# 85567   ['python', 'r', 'sql', 'azure', 'gcp', 'aws', ...
# 347995         ['python', 'sql', 'r', 'qlik', 'power bi']
# 39814                                          ['python']
# 137461  ['python', 'java', 'tensorflow', 'pytorch', 'k...
#
#                                           job_type_skills
# 53092   {'analyst_tools': ['ms access'], 'programming'...
# 517298  {'analyst_tools': ['tableau'], 'cloud': ['aws'...
# 586467  {'analyst_tools': ['word', 'ssis', 'power bi',...
# 260490                                               None
# 738510  {'analyst_tools': ['power bi', 'dax'], 'progra...
# 9592             {'os': ['unix'], 'programming': ['sql']}
# 85567   {'analyst_tools': ['tableau'], 'cloud': ['azur...
# 347995  {'analyst_tools': ['qlik', 'power bi'], 'progr...
# 39814                         {'programming': ['python']}
# 137461  {'libraries': ['tensorflow', 'pytorch'], 'othe...
